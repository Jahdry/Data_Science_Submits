# %% [markdown]
# # S18 T01: Tasca base de dades NoSQL

# %%
import pymongo
import pandas as pd

# %% [markdown]
# ## Nivell 1
# - Exercici 1
#
# Crea una base de dades NoSQL utilitzant MongoDB. Afegeix-li algunes dades d'exemple que et permetin comprovar que ets capaç de processar-ne la informació de manera bàsica.

# %% [markdown]
#  We've created an Atlas account (MongoDB cloud service) an deployed the example databases that comes into the service.
#
#  ![Atlas1](./Screenshots/Atlas1.png)
#
#  ![Atlas2](./Screenshots/Atlas2.png)

# %% [markdown]
# - Exercici 2
#
# Connecta la base de dades NoSQL a Python utilitzant per exemple pymongo.

# %%
conn_str = "mongodb+srv://Jahdry:6LPgTRZichCwxv3@warrior.nydx7.mongodb.net/"
myclient = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=5000)
myclient.list_database_names()
# Out:
# ['mydatabase_test',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
database_name = "mydatabase_test"
collection_name = "users"
user = {"username": "Vetusta", "email": "vetusta_13@fakemail.com", "pw": "fakepassword4", "Is_admin":True, "admin_level": 5}

mydb = myclient[database_name] #Create a new DB
mycol = mydb[collection_name] #Create a collection --> is the equivalent to a SQL table.

# %%
mycol.delete_many({}) # this line to delete the previous records
myrecord = mycol.insert_one(user) #Insert a record in the collection

if "mydatabase_test" in myclient.list_database_names(): #Check if the DB exists. The DB doesn't show up until it has a collection and data on it. 
    print(f"The database {database_name} exists.")
if "users" in mydb.list_collection_names(): # Check if the collection exists
    print(f"The collection {collection_name} exists:")
    for r in mycol.find(): # print the records of the collection
        print (r)
# Out:
# The database mydatabase_test exists.
# The collection users exists:
# {'_id': ObjectId('60e4261868c7675baafae520'), 'username': 'Vetusta', 'email': 'vetusta_13@fakemail.com', 'pw': 'fakepassword4', 'Is_admin': True, 'admin_level': 5}

# %%
# Create random records from the word list below:
user_list = ["Blanquet", "Pilgrm", "Ford", "Garrison", "Stormtrooper", "Milwakee", "Cliford", "Saturna", "Hugaceo", "Mad_Racoon", "Tolkien", "Matilda", "SuperSayan"]
users = []
n = 1
a = 0

for i in user_list:
    users.append({"_id":n, "username": i, "email": f"{i}_{n}@fakemail.com".lower(), "pw": f"fakepassword{n}", "Is_admin":False})
    if n % 3 == 0: 
        users[a].update({"Is_admin":True, "admin_level": int(n/3)}) # if the Id is divisble by 3 this user is an admin and has "admin_level" attribute
    n += 1
    a += 1

for i in users: 
    print(i)
# Out:
# {'_id': 1, 'username': 'Blanquet', 'email': 'blanquet_1@fakemail.com', 'pw': 'fakepassword1', 'Is_admin': False}
# {'_id': 2, 'username': 'Pilgrm', 'email': 'pilgrm_2@fakemail.com', 'pw': 'fakepassword2', 'Is_admin': False}
# {'_id': 3, 'username': 'Ford', 'email': 'ford_3@fakemail.com', 'pw': 'fakepassword3', 'Is_admin': True, 'admin_level': 1}
# {'_id': 4, 'username': 'Garrison', 'email': 'garrison_4@fakemail.com', 'pw': 'fakepassword4', 'Is_admin': False}
# {'_id': 5, 'username': 'Stormtrooper', 'email': 'stormtrooper_5@fakemail.com', 'pw': 'fakepassword5', 'Is_admin': False}
# {'_id': 6, 'username': 'Milwakee', 'email': 'milwakee_6@fakemail.com', 'pw': 'fakepassword6', 'Is_admin': True, 'admin_level': 2}
# {'_id': 7, 'username': 'Cliford', 'email': 'cliford_7@fakemail.com', 'pw': 'fakepassword7', 'Is_admin': False}
# {'_id': 8, 'username': 'Saturna', 'email': 'saturna_8@fakemail.com', 'pw': 'fakepassword8', 'Is_admin': False}
# {'_id': 9, 'username': 'Hugaceo', 'email': 'hugaceo_9@fakemail.com', 'pw': 'fakepassword9', 'Is_admin': True, 'admin_level': 3}
# {'_id': 10, 'username': 'Mad_Racoon', 'email': 'mad_racoon_10@fakemail.com', 'pw': 'fakepassword10', 'Is_admin': False}
# {'_id': 11, 'username': 'Tolkien', 'email': 'tolkien_11@fakemail.com', 'pw': 'fakepassword11', 'Is_admin': False}
# {'_id': 12, 'username': 'Matilda', 'email': 'matilda_12@fakemail.com', 'pw': 'fakepassword12', 'Is_admin': True, 'admin_level': 4}
# {'_id': 13, 'username': 'SuperSayan', 'email': 'supersayan_13@fakemail.com', 'pw': 'fakepassword13', 'Is_admin': False}

# %%
x = mycol.insert_many(users) # Insertin multiple records into collection
for r in mycol.find(): # print the records
        print (r)
# Out:
# {'_id': ObjectId('60e4261868c7675baafae520'), 'username': 'Vetusta', 'email': 'vetusta_13@fakemail.com', 'pw': 'fakepassword4', 'Is_admin': True, 'admin_level': 5}
# {'_id': 1, 'username': 'Blanquet', 'email': 'blanquet_1@fakemail.com', 'pw': 'fakepassword1', 'Is_admin': False}
# {'_id': 2, 'username': 'Pilgrm', 'email': 'pilgrm_2@fakemail.com', 'pw': 'fakepassword2', 'Is_admin': False}
# {'_id': 3, 'username': 'Ford', 'email': 'ford_3@fakemail.com', 'pw': 'fakepassword3', 'Is_admin': True, 'admin_level': 1}
# {'_id': 4, 'username': 'Garrison', 'email': 'garrison_4@fakemail.com', 'pw': 'fakepassword4', 'Is_admin': False}
# {'_id': 5, 'username': 'Stormtrooper', 'email': 'stormtrooper_5@fakemail.com', 'pw': 'fakepassword5', 'Is_admin': False}
# {'_id': 6, 'username': 'Milwakee', 'email': 'milwakee_6@fakemail.com', 'pw': 'fakepassword6', 'Is_admin': True, 'admin_level': 2}
# {'_id': 7, 'username': 'Cliford', 'email': 'cliford_7@fakemail.com', 'pw': 'fakepassword7', 'Is_admin': False}
# {'_id': 8, 'username': 'Saturna', 'email': 'saturna_8@fakemail.com', 'pw': 'fakepassword8', 'Is_admin': False}
# {'_id': 9, 'username': 'Hugaceo', 'email': 'hugaceo_9@fakemail.com', 'pw': 'fakepassword9', 'Is_admin': True, 'admin_level': 3}
# {'_id': 10, 'username': 'Mad_Racoon', 'email': 'mad_racoon_10@fakemail.com', 'pw': 'fakepassword10', 'Is_admin': False}
# {'_id': 11, 'username': 'Tolkien', 'email': 'tolkien_11@fakemail.com', 'pw': 'fakepassword11', 'Is_admin': False}
# {'_id': 12, 'username': 'Matilda', 'email': 'matilda_12@fakemail.com', 'pw': 'fakepassword12', 'Is_admin': True, 'admin_level': 4}
# {'_id': 13, 'username': 'SuperSayan', 'email': 'supersayan_13@fakemail.com', 'pw': 'fakepassword13', 'Is_admin': False}

# %% [markdown]
# Note that as we did not determined the "_id" of the first record Mongo assigned a uniqueID automaticaly.

# %% [markdown]
# ## Nivell 2
#
# - Exercici 1
#
# Carrega algunes consultes senzilles a un Pandas Dataframe.

# %%
for x in mycol.find({'Is_admin':True}):
    print(x)
# Out:
# {'_id': ObjectId('60e4261868c7675baafae520'), 'username': 'Vetusta', 'email': 'vetusta_13@fakemail.com', 'pw': 'fakepassword4', 'Is_admin': True, 'admin_level': 5}
# {'_id': 3, 'username': 'Ford', 'email': 'ford_3@fakemail.com', 'pw': 'fakepassword3', 'Is_admin': True, 'admin_level': 1}
# {'_id': 6, 'username': 'Milwakee', 'email': 'milwakee_6@fakemail.com', 'pw': 'fakepassword6', 'Is_admin': True, 'admin_level': 2}
# {'_id': 9, 'username': 'Hugaceo', 'email': 'hugaceo_9@fakemail.com', 'pw': 'fakepassword9', 'Is_admin': True, 'admin_level': 3}
# {'_id': 12, 'username': 'Matilda', 'email': 'matilda_12@fakemail.com', 'pw': 'fakepassword12', 'Is_admin': True, 'admin_level': 4}

# %%
for x in mycol.find({"admin_level":{"$gte":3}}, {"_id":0, "email":0, "pw":0}).sort("username"): # users with "admin_level >= 3 and sorted by username"
    print(x)
# Out:
# {'username': 'Hugaceo', 'Is_admin': True, 'admin_level': 3}
# {'username': 'Matilda', 'Is_admin': True, 'admin_level': 4}
# {'username': 'Vetusta', 'Is_admin': True, 'admin_level': 5}

# %% [markdown]
# At this point I realize that the attribute "Is_admin" is irrelevant as the self existance of the field "admin_level" determines if the user is admin or not.

# %%
# For the next queries change the database to another one of the test databases that Atlas provides. 

database_name = "sample_mflix"
mydb = myclient[database_name] #Create a new DB
mydb.list_collection_names()
# Out:
# ['comments', 'sessions', 'movies', 'users', 'theaters']

# %%
mycol = mydb["movies"]

# Search for all movies with ranting <= 8 in IMDB that are described as a masterpiece by the critic.

cursor = mycol.find({"imdb.rating":{"$lte":8}, "tomatoes.consensus":{"$regex":"masterpiece"}}, {"_id":False, "plot":False, "poster":False, "fullplot":False, "tomatoes.consensus":False}).sort("generes")
movies_df = pd.DataFrame(list(cursor))
movies_df
# Out:
#                        genres  runtime      rated  \
# 0                    [Horror]       81    UNRATED
# 1              [History, War]       66    UNRATED
# 2                    [Horror]       81    UNRATED
# 3                [Drama, War]       78  NOT RATED
# 4            [Drama, Mystery]      115         PG
# 5  [Horror, Mystery, Romance]      126          X
# 6                     [Drama]      242      PG-13
# 7              [Crime, Drama]      137  NOT RATED
# 8                     [Drama]       70  NOT RATED
#
#                                                 cast                   title  \
# 0  [Max Schreck, Gustav von Wangenheim, Greta Sch...               Nosferatu
# 1  [Aleksandr Antonov, Vladimir Barsky, Grigori A...     Battleship Potemkin
# 2  [Max Schreck, Gustav von Wangenheim, Greta Sch...               Nosferatu
# 3  [Edmund Moeschke, Ernst Pittschau, Ingetraud H...       Germany Year Zero
# 4  [Rachel Roberts, Vivean Gray, Helen Morse, Kir...  Picnic at Hanging Rock
# 5  [David Hemmings, Daria Nicolodi, Gabriele Lavi...                Deep Red
# 6  [Riz Abbasi, Richard Attenborough, David Blair...                  Hamlet
# 7  [Salvatore Abruzzese, Simone Sacchettino, Salv...                Gomorrah
# 8  [Hèloèse Godet, Kamel Abdeli, Richard Chevalli...     Goodbye to Language
#
#                                  languages   released               directors  \
# 0                                 [German] 1929-06-03           [F.W. Murnau]
# 1                                [Russian] 1925-12-24  [Sergei M. Eisenstein]
# 2                                 [German] 1929-06-03           [F.W. Murnau]
# 3                [German, English, French] 1949-09-19    [Roberto Rossellini]
# 4                        [English, French] 1979-02-02            [Peter Weir]
# 5                                [Italian] 1976-06-11         [Dario Argento]
# 6                                [English] 1996-12-25       [Kenneth Branagh]
# 7  [Neapolitan, Italian, Mandarin, French] 2009-04-10        [Matteo Garrone]
# 8                        [French, English] 2014-05-28       [Jean-Luc Godard]
#
#                                              writers  \
# 0  [Henrik Galeen (screen play), Bram Stoker (bas...
# 1                     [Nina Agadzhanova (script by)]
# 2  [Henrik Galeen (screen play), Bram Stoker (bas...
# 3  [Roberto Rossellini (screenplay), Roberto Ross...
# 4   [Joan Lindsay (novel), Cliff Green (screenplay)]
# 5   [Dario Argento, Bernardino Zapponi (screenplay)]
# 6  [William Shakespeare (play), Kenneth Branagh (...
# 7  [Roberto Saviano (book), Maurizio Braucci (scr...
# 8                                  [Jean-Luc Godard]
#
#                                               awards  \
# 0  {'wins': 1, 'nominations': 1, 'text': '1 win &...
# 1    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 2  {'wins': 1, 'nominations': 1, 'text': '1 win &...
# 3   {'wins': 3, 'nominations': 0, 'text': '3 wins.'}
# 4  {'wins': 4, 'nominations': 11, 'text': 'Won 1 ...
# 5  {'wins': 1, 'nominations': 1, 'text': '1 win &...
# 6  {'wins': 13, 'nominations': 18, 'text': 'Nomin...
# 7  {'wins': 31, 'nominations': 28, 'text': 'Nomin...
# 8  {'wins': 5, 'nominations': 11, 'text': '5 wins...
#
#                      lastupdated  year  \
# 0  2015-08-21 00:04:53.453000000  1922
# 1  2015-08-18 00:22:19.750000000  1925
# 2  2015-09-07 07:20:20.853000000  1922
# 3  2015-08-17 01:04:11.080000000  1948
# 4  2015-08-23 00:27:24.657000000  1975
# 5  2015-08-25 01:01:19.510000000  1975
# 6  2015-08-26 00:04:20.760000000  1996
# 7  2015-08-30 00:01:52.650000000  2008
# 8  2015-08-30 00:30:55.087000000  2014
#
#                                             imdb                 countries  \
# 0   {'rating': 8.0, 'votes': 63322, 'id': 13442}                 [Germany]
# 1   {'rating': 8.0, 'votes': 36901, 'id': 15648}            [Soviet Union]
# 2   {'rating': 8.0, 'votes': 63557, 'id': 13442}                 [Germany]
# 3    {'rating': 7.9, 'votes': 6149, 'id': 39417}  [Italy, France, Germany]
# 4   {'rating': 7.6, 'votes': 23277, 'id': 73540}               [Australia]
# 5   {'rating': 7.7, 'votes': 19144, 'id': 73582}                   [Italy]
# 6  {'rating': 7.8, 'votes': 29078, 'id': 116477}                 [UK, USA]
# 7  {'rating': 7.0, 'votes': 36065, 'id': 929425}                   [Italy]
# 8  {'rating': 5.9, 'votes': 3002, 'id': 2400275}     [Switzerland, France]
#
#     type                                           tomatoes  \
# 0  movie  {'viewer': {'rating': 4.0, 'numReviews': 46806...
# 1  movie  {'viewer': {'rating': 4.0, 'numReviews': 18323...
# 2  movie  {'viewer': {'rating': 4.0, 'numReviews': 46806...
# 3  movie  {'viewer': {'rating': 4.0, 'numReviews': 2590,...
# 4  movie  {'viewer': {'rating': 3.9, 'numReviews': 10042...
# 5  movie  {'viewer': {'rating': 4.0, 'numReviews': 11171...
# 6  movie  {'viewer': {'rating': 3.8, 'numReviews': 32056...
# 7  movie  {'website': 'http://www.gomorra-lefilm.com/', ...
# 8  movie  {'viewer': {'rating': 3.1, 'numReviews': 3160,...
#
#    num_mflix_comments  metacritic
# 0                 NaN         NaN
# 1                 1.0         NaN
# 2                 1.0         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
# 5                 1.0         NaN
# 6                 1.0         NaN
# 7                 3.0        87.0
# 8                 2.0        75.0

# %% [markdown]
# ## Nivell 3
#
# - Exercici 1
#
# Genera un resum estadístic de la informació que conté la base de dades.

# %%
# Accesing the DB we've created before
mydb = myclient["mydatabase_test"] 
mycol = mydb["users"]

# %%
#Retrieving the entire data to a pandas DatFrame

cursor = mycol.find({})
users_df = pd.DataFrame(list(cursor))
users_df
# Out:
#                          _id      username                        email  \
# 0   60e4261868c7675baafae520       Vetusta      vetusta_13@fakemail.com
# 1                          1      Blanquet      blanquet_1@fakemail.com
# 2                          2        Pilgrm        pilgrm_2@fakemail.com
# 3                          3          Ford          ford_3@fakemail.com
# 4                          4      Garrison      garrison_4@fakemail.com
# 5                          5  Stormtrooper  stormtrooper_5@fakemail.com
# 6                          6      Milwakee      milwakee_6@fakemail.com
# 7                          7       Cliford       cliford_7@fakemail.com
# 8                          8       Saturna       saturna_8@fakemail.com
# 9                          9       Hugaceo       hugaceo_9@fakemail.com
# 10                        10    Mad_Racoon   mad_racoon_10@fakemail.com
# 11                        11       Tolkien      tolkien_11@fakemail.com
# 12                        12       Matilda      matilda_12@fakemail.com
# 13                        13    SuperSayan   supersayan_13@fakemail.com
#
#                 pw  Is_admin  admin_level
# 0    fakepassword4      True          5.0
# 1    fakepassword1     False          NaN
# 2    fakepassword2     False          NaN
# 3    fakepassword3      True          1.0
# 4    fakepassword4     False          NaN
# 5    fakepassword5     False          NaN
# 6    fakepassword6      True          2.0
# 7    fakepassword7     False          NaN
# 8    fakepassword8     False          NaN
# 9    fakepassword9      True          3.0
# 10  fakepassword10     False          NaN
# 11  fakepassword11     False          NaN
# 12  fakepassword12      True          4.0
# 13  fakepassword13     False          NaN

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _id          14 non-null     object
#  1   username     14 non-null     object
#  2   email        14 non-null     object
#  3   pw           14 non-null     object
#  4   Is_admin     14 non-null     bool
#  5   admin_level  5 non-null      float64
# dtypes: bool(1), float64(1), object(4)
# memory usage: 702.0+ bytes

# %%
# Showing the statistics of the DB:
users_df.describe(include="all")
# Out:
#          _id username                    email             pw Is_admin  \
# count   14.0       14                       14             14       14
# unique  14.0       14                       14             13        2
# top      1.0  Cliford  milwakee_6@fakemail.com  fakepassword4    False
# freq     1.0        1                        1              2        9
# mean     NaN      NaN                      NaN            NaN      NaN
# std      NaN      NaN                      NaN            NaN      NaN
# min      NaN      NaN                      NaN            NaN      NaN
# 25%      NaN      NaN                      NaN            NaN      NaN
# 50%      NaN      NaN                      NaN            NaN      NaN
# 75%      NaN      NaN                      NaN            NaN      NaN
# max      NaN      NaN                      NaN            NaN      NaN
#
#         admin_level
# count      5.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean       3.000000
# std        1.581139
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000

# %% [markdown]
# In order to resume statistically some of the features on sample_mflix DB (Test DB Atlas mongo cloud service) we've created and [Interactive Dashboard](https://charts.mongodb.com/charts-tasca18-mspka/public/dashboards/60df227c-e219-496c-8607-b4068dc95752) with Atlas Charts.
#
#
#  ![Atlas_Dashboard](./Screenshots/MoviesDashboard.png)
