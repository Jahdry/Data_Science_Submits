# %% [markdown]
# # TASCA 1: Jupyter Notebook

# %% [markdown]
# ![Jupyter_logo.png](attachment:Jupyter_logo.png)

# %% [markdown]
# ## Declaració de variables
#
# les variables es creen automaticament el primer cop que s'assignen.
# Per assignar una varable s'utilitza el signe **"="**
#
#
# Diferents **_tipus de dades_**:
#
# * Numériques
#     * integers
#     * floats
# * strings
# * boleans

# %%
name = "Adrià"
age = 38
height_m = 1.83
adress = "adria38@mail.fake"
married = False

# %% [markdown]
# ## Operacions aritètiques
#
# ### Suma

# %%
15 + 4
# Out:
# 19

# %% [markdown]
# ### Mòdul

# %%
7 % 2
# Out:
# 1

# %%
estat_civil = ""
if married == False: 
    estat_civil = "solter"
else: 
    estat_civil = "casat"

# %% [markdown]
# ## Operacions amb Strings
#
# Per sumar altres tipus de dades a una cadena de strings primer s'han de convertir mitjançant el métode str()

# %%
print ("Hola em dic " + name + " tinc " + str(age) + " i actualment estic " + estat_civil + ".")
# Out:
# Hola em dic Adrià tinc 38 i actualment estic solter.
